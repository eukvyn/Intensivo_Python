# %%
#Importar as bibliotecas
import pyautogui # Automação do mouse e teclado
import time # Controla o tempo no programa
import pyperclip # Permite copiar e colar com o python]
import pandas as pd

pyautogui.Pause = 2 # Configurando o Pytautogui pra esperar 1 segundo pra cada comando executado

pyautogui.alert('O programa vai começar. Não use NADA do seu computador enquanto esse programa estiver sendo executado')

#Passo 1: Entrar no sistema (link do google drive)
pyautogui.hotkey('ctrl', 't') 
# Fazer o computador usar um atalho do teclado
link = 'https://drive.google.com/drive/folders/1mhXZ3JPAnekXP_4vX7Z_sJj35VWqayaR?usp=sharing'
pyperclip.copy(link) 
# Fazer o computador Copiar o texto com o Pyperclip
pyautogui.hotkey('ctrl', 'v')
# Fazer o computador usar um atalho do teclado pra colar um texto
pyautogui.press('enter')
# Fazer o computador usar uma tecla do teclado
time.sleep(3)
# Fazer o compputador "dormir" por 3 segundos enquanto a página carrega

#Passo 2: Entra na pasta da aula 1
#   Lógica para descobrir as cordenadas da sua tela : 
#   time.sleep(5) # Fazer o programa esperar entquanto você posiciona o mouse na aba e posição que quiser
#   pyautogui.position() --> Comando que descobre as cordenadas da tela, de acordo com a posição do seu mouse
pyautogui.click(370, 337, clicks=2)
# Fazer o mouse clicar na tela, de acordo com as cordenadas x e y passadas como parâmetro


#Passo 3: Fazer o sownload da Base de Vendas
# 3 clicks seguido no mouse para fazer o download do arquivo
time.sleep(3)
pyautogui.click(1234, 543)
time.sleep(1)
pyautogui.click(1661, 204)
time.sleep(1)
pyautogui.click(1373, 738)
time.sleep(10) # Esperar o download ser concluido

#Passo 4: Calcular os indicadores (Faturamento e a quantidade de Produtos)

tabela = pd.read_excel(r'C:\Users\janio\Downloads\Vendas - Dez.xlsx') # Ler um arquivo excel
display(tabela) # Um print mais estilisado, melhor para visualisar tabelas
faturamento = tabela["Valor Final"].sum()
qtde_produtos = tabela["Quantidade"].sum()

#passo 5: Entrar no meu email
# email da diretoria: janioklalmeida05+diretoria@gmail.com

pyautogui.hotkey('ctrl', 't') 
# abrir nova aba
link = 'https://mail.google.com/'
pyperclip.copy(link) 
# Copiar o texto com o Pyperclip
pyautogui.hotkey('ctrl', 'v')
# Atalho do teclado pra colar um texto
pyautogui.press('enter')
# Pressionar uma tecla do teclado
time.sleep(5)
# Fazer o computador "dormir" por 5 segundos enquanto a página carrega

#Passo 6: Criar o email
pyautogui.click(45, 214)
time.sleep(2)

#escolher o email
pyautogui.write('janioklalmeida05+diretoria@gmail.com')
pyautogui.press('tab')

# Preencher o assunto
pyautogui.press('tab')
assunto = 'Relatório de Vendas'
pyperclip.copy(assunto)
pyautogui.hotkey('ctrl', 'v')

# Preencher o email
pyautogui.press('tab')
texto_email = f"""
Prezados, Bom dia

O faturamento foi de: R${faturamento:,.2f}
A quantidade de produtos foi: {qtde_produtos:,}

Abs
Kvyn Mc
"""
pyperclip.copy(texto_email)
pyautogui.hotkey('ctrl', 'v')
time.sleep(1)

#Passo 7: Enviar o email
pyautogui.hotkey('ctrl', 'enter')
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
import time
import pyautogui
time.sleep(5) # Fazer o programa esperar entquanto você posiciona o mouse na aba e posição que quiser
pyautogui.position() # --> Comando que descobre as cordenadas da tela, de acordo com a posição do seu mouse
# Out:
# Point(x=1373, y=738)
